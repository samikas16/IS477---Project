# %%
#imports
import pandas as pd

# %%
df = pd.read_csv("annual_aqi_by_cbsa_2024.csv")
df.head()
# Out:
#            CBSA  CBSA Code  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Aberdeen, SD      10100  2024            357        306             47
# 1  Aberdeen, WA      10140  2024            366        353             13
# 2       Ada, OK      10220  2024            289        207             81
# 3    Adrian, MI      10300  2024            366        253            113
# 4     Akron, OH      10420  2024            341        216            123
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    4               0                    0
# 1                                    0               0                    0
# 2                                    1               0                    0
# 3                                    0               0                    0
# 4                                    2               0                    0
#
# ...

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (501, 18)
# CBSA                                   object
# CBSA Code                               int64
# Year                                    int64
# Days with AQI                           int64
# Good Days                               int64
# Moderate Days                           int64
# Unhealthy for Sensitive Groups Days     int64
# Unhealthy Days                          int64
# Very Unhealthy Days                     int64
# Hazardous Days                          int64
# Max AQI                                 int64
# 90th Percentile AQI                     int64
# Median AQI                              int64
# Days CO                                 int64
# Days NO2                                int64
# Days Ozone                              int64
# Days PM2.5                              int64
# Days PM10                               int64
# dtype: object
# CBSA                                   0
# CBSA Code                              0
# ...

# %%
#Dataset Cleaning
df = df.dropna()
df = df.drop_duplicates()

df.shape
# Out:
# (501, 19)

# %%
df.describe()
# Out:
#           CBSA Code    Year  Days with AQI   Good Days  Moderate Days  \
# count    501.000000   501.0     501.000000  501.000000     501.000000
# mean   29932.614770  2024.0     342.610778  237.301397      99.483034
# std    11415.684603     0.0      60.396011   72.328715      63.051584
# min    10100.000000  2024.0      31.000000   25.000000       0.000000
# 25%    20060.000000  2024.0     359.000000  198.000000      49.000000
# 50%    29660.000000  2024.0     366.000000  246.000000      90.000000
# 75%    40060.000000  2024.0     366.000000  291.000000     141.000000
# max    49740.000000  2024.0     366.000000  364.000000     267.000000
#
#        Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# count                           501.000000      501.000000
# mean                              4.732535        0.912176
# std                              11.366984        4.615222
# min                               0.000000        0.000000
# ...

# %%
#Average AQIs for each 
f[["Good Days","Moderate Days", "Unhealthy for Sensitive Groups Days","Unhealthy Days","Very Unhealthy Days", "Hazardous Days"]].mean()
# Out:
# Good Days                              237.301397
# Moderate Days                           99.483034
# Unhealthy for Sensitive Groups Days      4.732535
# Unhealthy Days                           0.912176
# Very Unhealthy Days                      0.135729
# Hazardous Days                           0.045908
# dtype: float64

# %%
#Worst AQIs
df.groupby("CBSA")["Median AQI"].mean().sort_values(ascending=False).head()
# Out:
# CBSA
# Riverside-San Bernardino-Ontario, CA    97.0
# Phoenix-Mesa-Scottsdale, AZ             86.0
# Los Angeles-Long Beach-Anaheim, CA      80.0
# Bakersfield, CA                         72.0
# San Diego-Carlsbad, CA                  71.0
# Name: Median AQI, dtype: float64

# %%
#Best AQIs
df.groupby("CBSA")["Median AQI"].mean().sort_values(ascending=True).head()
# Out:
# CBSA
# Ponce, PR        3.0
# Evanston, WY     7.0
# Pierre, SD       8.0
# Mayaguez, PR    11.0
# Houghton, MI    12.0
# Name: Median AQI, dtype: float64
